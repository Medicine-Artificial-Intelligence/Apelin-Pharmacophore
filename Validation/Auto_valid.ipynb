# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append('./Ph4')
from Postprocessing import pharmacophore_postprocess
from Validation import pharmacophore_validation
from Autoresult import autoph4result
import warnings
warnings.filterwarnings('ignore')

# %%
# Database
dekois1 = pd.read_csv("Apelin_search_standard_cps1.csv")
dekois2 = pd.read_csv("Apelin_search_standard.csv")

# %%
# 3.Check automation
import os
path1 = os.getcwd() + '/Data2/'
path2 = os.getcwd() + '/Data/'

# %%
auto1 = autoph4result(path = path1, ref=dekois1, scores = 'rmsd', active = 'Active', ID = 'ID', 
                     rescore = 'minmax', auc_thresh = 0.7, figsize = (9,6.5))
auto1.compare_model_multi()
# Out:
# Train set A result

# %%
auto = autoph4result(path = path2, ref=dekois2, scores = 'rmsd', active = 'Active', ID = 'ID', 
                     rescore = 'minmax', auc_thresh = 0.7, figsize = (9,6.5))
auto.compare_model_multi()
# Out:
# Train set B result
# Train set C result
# Train set D result
# Train set E result
